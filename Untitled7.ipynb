# %% [markdown]
# <a href="https://colab.research.google.com/github/chritson2004/Introduction-to-python/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
supermarket=files.upload()
# Out:
#      <input type="file" id="files-0b7ab477-00df-44e5-8467-f146216d76ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0b7ab477-00df-44e5-8467-f146216d76ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
teams_and_leagues=files.upload()
# Out:
#      <input type="file" id="files-e8f9e70d-9209-4845-bdd9-f229774338ed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8f9e70d-9209-4845-bdd9-f229774338ed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
teamgoals=pd.DataFrame({'teams':['spain','england'],'goals':[2,4]})
print(teamgoals)
# Out:
#      teams  goals
# 0    spain      2
# 1  england      4

# %%
import pandas as pd
match=pd.DataFrame({'Players':['messi','ronaldo'],'country':['argentina','portugal']})
print(match)
# Out:
#    Players    country
# 0    messi  argentina
# 1  ronaldo   portugal

# %%
import pandas as pd
sub=['hindi','english','fa','cra','dmbs']
mark=[30,40,50,67,80]
mark1={'subject':sub,'marks':mark}
marks=pd.DataFrame(sub,mark)
print(marks)
# Out:
#           0
# 30    hindi
# 40  english
# 50       fa
# 67      cra
# 80     dmbs

# %%
import pandas as pd
dataframe=pd.read_csv('Supermarket_sales.csv')
#print(dataframe)
print("********")
print(dataframe.head(5))
print(dataframe['City'])
print(dataframe[['Branch','Customertype']])

for i in dataframe.index:
  print(dataframe.City[i],dataframe.Branch[i])

# %%
from google.colab import files
players_20=files.upload()
# Out:
#      <input type="file" id="files-fae70dbd-0727-4e7f-9a9d-36bcdec6902a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fae70dbd-0727-4e7f-9a9d-36bcdec6902a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df2=pd.read_csv('players_20.csv')
max=df2.overall.max()
max2=df2.age.max()
age=df2.age.mean()
#overall=df2.overall.Avg()
#max1=df2.overall.idxmax()
#per=df2.loc[max_overall_loc]
#print(person.long_name,'has the highest overall of',max_overall)
#print(overall)
for i in df2.index:
  if df2.club[i]=='FC Barcelona':
    print(df2.short_name[i])
# Out:
# L. Messi
# M. ter Stegen
# L. Suárez
# Sergio Busquets
# A. Griezmann
# Piqué
# Jordi Alba
# S. Umtiti
# I. Rakitić
# F. de Jong
# C. Lenglet
# Neto
# O. Dembélé
# Arthur
# A. Vidal
# Nélson Semedo
# Sergi Roberto
# Rafinha
# Junior Firpo
# Aleñá
# Riqui Puig
# J. Todibo
# M. Wagué
# H. Abe
# L. Reis
# Abel Ruiz
# Oriol Busquets
# Carles Pérez
# Miranda
# Chumi
# Álex Collado
# Jorge Cuenca
# Iñaki Peña
